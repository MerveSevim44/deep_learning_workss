# %% [markdown]
# # Markdown Examples2
#
# ## Headers
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6
#
# ## Emphasis
# **This is bold text**
# __This is also bold__
#
# *This is italic text*
# _This is also italic_
#
# ***This is bold and italic***
#
# ## Lists
#
# ### Unordered
# - Item 1
# - Item 2
#   - Subitem 2.1
#   - Subitem 2.2
#
# ### Ordered
# 1. First item
# 2. Second item
# 3. Third item
#
# ## Links
# [Google](http://www.google.com)
#
# ## Images
# ![This is an image](https://via.placeholder.com/150)
#
# ## Code
#
#
# ## Blockquotes
#
# > This is a blockquote.
# >
# > This is part of the same quote.
#
# ## Tables
#
# | Column 1 | Column 2 | Column 3 |
# | -------- | -------- | -------- |
# | Row 1, Col 1 | Row 1, Col 2 | Row 1, Col 3 |
# | Row 2, Col 1 | Row 2, Col 2 | Row 2, Col 3 |
# | Row 3, Col 1 | Row 3, Col 2 | Row 3, Col 3 |
#
# ## Horizontal Rules
#
# ---
#
# ## HTML Elements
#
# You can also use raw HTML in your Markdown, and it will be rendered nicely.
#
# <b>This is bold text but written in HTML</b>

# %%
print("hello ai era")
# Out:
# hello ai era
